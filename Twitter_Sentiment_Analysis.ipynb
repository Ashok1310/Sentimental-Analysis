# %%
# !pip install pandas
# !pip install tweepy
#!pip install vaderSentiment

# %%
import pandas as pd
import tweepy 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
consumer_key = 'i49ZJTEjfBRn4H0XrVmYt1Msg'
consumer_secret = 'XLWWdlKT9PJPfj8WcJ4JnYrfIXwgIuzlSN9Mw58zohZrC59uML'
access_token = '788957252464046080-eGveAM7hdgZ6Ue57VYjLBxGnwG6Xg8C'
access_token_secret = 'pXxDNqzKdEK7o9318ncDLzB9yVj1x1dte9J3xRfZxzlNm'

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)

# %%
tweets=api.search("Artificial Intelligence",count=200)

# %%
data=pd.DataFrame(data=[tweet.text for tweet in tweets],columns=['Tweets'])
display(data.head(10))
print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @ipfconline1: Artificial Intelligence an “A...
# 1  RT @SpirosMargaris: Honor to be among great na...
# 2  7 Indicators Of The State-Of-Artificial Intell...
# 3  RT @modernimprint: #ArtificialIntelligence, #M...
# 4          RT @sofeelings00: https://t.co/UKhGUIXxxc
# 5  RT @stpiindia: To address the rising gaps betw...
# 6  Healthcare Artificial Intelligence Group Forms...
# 7  RT @triipme: This generation wants brands to d...
# 8  Can Artificial Intelligence Be Conscious? via ...
# 9  RT @david_green_uk: IBM artificial intelligenc...
# 2019-04-09 11:44:10

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid=SentimentIntensityAnalyzer()

# %%
listy=[]
for index,row in data.iterrows():
  ss=sid.polarity_scores(row["Tweets"])
  listy.append(ss)
se=pd.Series(listy)
data['polarity']=se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @ipfconline1: Artificial Intelligence an “A...
# 1   RT @SpirosMargaris: Honor to be among great na...
# 2   7 Indicators Of The State-Of-Artificial Intell...
# 3   RT @modernimprint: #ArtificialIntelligence, #M...
# 4           RT @sofeelings00: https://t.co/UKhGUIXxxc
# 5   RT @stpiindia: To address the rising gaps betw...
# 6   Healthcare Artificial Intelligence Group Forms...
# 7   RT @triipme: This generation wants brands to d...
# 8   Can Artificial Intelligence Be Conscious? via ...
# 9   RT @david_green_uk: IBM artificial intelligenc...
# 10  RT @StephaneNappo: Artificial Intelligence pre...
# 11  RT @SmalsResearch: The EU published a set of g...
# 12  RT @Amani_Sinan: mHealth Data to Play Big Role...
# 13          RT @sofeelings00: https://t.co/LrYGmyZA0H
# 14         RT @norwayspariss: https://t.co/Ol50RULaST
# 15  RT @Zanfa: Crianças do meu Brasil:\n\nEstudem ...
# ...
